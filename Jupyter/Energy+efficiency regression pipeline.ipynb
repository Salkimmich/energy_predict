# %% [markdown]
# This notebook uses the best parameters found in _Energy+efficiency dataset EDA and Regression.ipynb_ for the `ExtraTreesRegressor` when training our model. All steps are wrapped up as chain links in a pipeline. This pipeline takes the data, preprocess it and trains the model at the same time. Finally the model will be saved using `joblib` package, in order to use use it later, without the need to retrain it.

# %%
# Import libraries
import joblib
import numpy as np
import pandas as pd
import sklearn
from joblib import dump, load
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
# Versions of the main packages. Will be needed for the docker enviroment(??)
print('Numpy version:', np.__version__)
print('Pandas version:', pd.__version__)
print('Scikit-learn version:', sklearn.__version__)
print('Joblib version:', joblib.__version__)
# Out:
# Numpy version: 1.18.5
# Pandas version: 1.0.4
# Scikit-learn version: 0.23.1
# Joblib version: 0.15.1

# %%
# Names of columns
columns = ['relative_compactness', 'surface_area', 'wall_area', 'roof_area', 'overall_height',
           'orientation', 'glazing_area', 'glazing_area_distribution', 'heating_load', 'cooling_load']

# Read data
df = pd.read_excel(
    'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx', names=columns, header=0)

# %% [markdown]
# # Data Preprocessing

# %%
# Split data to X and y
X = df.drop(['heating_load', 'cooling_load'], axis=1)
y = df[['heating_load', 'cooling_load']]

# %%
# Split to X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=0)

# %%
# Create a standard scaler
scaler = StandardScaler()

# Create an Extra tree regressor with the known best parameters
# {'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 22, 'n_estimators': 44}
etr = ExtraTreesRegressor(max_depth=8, min_samples_leaf=5,
                          min_samples_split=22, n_estimators=44, random_state=0)

# %% [markdown]
# # Modeling

# %%
# create a pipeline to wrap the scaler and regressor
pipe = make_pipeline(scaler, etr)

# Train the pipeline
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('extratreesregressor',
#                  ExtraTreesRegressor(max_depth=8, min_samples_leaf=5,
#                                      min_samples_split=22, n_estimators=44,
#                                      random_state=0))])

# %%
# Score of the model
pipe.score(X_test, y_test)
# Out:
# 0.9813522771767467

# %%
# Saving the model
dump(pipe, 'model.joblib')
# Out:
# ['model.joblib']

# %%
# Testing the loaded model
model = load('model.joblib')

# %%
# Predictions of the loaded model for X_test
model.predict(X_test)
# Out:
# array([[15.21076923, 17.95384615],
#        [10.32466667, 13.49066667],
#        [36.00271808, 38.47570084],
#        [19.06782541, 25.37542872],
#        [32.5233079 , 33.39104329],
#        [28.96916667, 31.3025    ],
#        [28.5075    , 29.769375  ],
#        [29.13841783, 30.75102819],
#        [29.27466667, 31.22266667],
#        [23.56      , 26.71615385],
#        [ 6.72794148, 11.7734517 ],
#        [41.90538462, 43.39538462],
#        [11.51603749, 14.45692641],
#        [41.90538462, 43.39538462],
#        [41.90538462, 43.39538462],
#        [26.32      , 28.603125  ],
#        [10.67      , 13.965     ],
#        [28.96916667, 31.3025    ],
#        [14.34473661, 15.13146929],
#        [12.21421982, 15.00660693],
#        [12.65374148, 15.48288447],
#        [32.5233079 , 33.39104329],
#        [10.67      , 13.965     ],
#        [39.10275036, 41.11082517],
#        [ 6.72794148, 11.7734517 ],
#        [14.44373605, 16.82592951],
#        [12.60714155, 14.13397658],
#        [13.93720473, 16.32996951],
#        [10.67      , 13.965     ],
#        [39.1330124 , 41.11121822],
#        [12.47805855, 14.07989042],
#        [12.94323402, 15.94223909],
#        [41.90538462, 43.39538462],
#        [12.90796237, 15.92792308],
#        [28.5075    , 29.769375  ],
#        [36.4273961 , 36.86462013],
#        [14.24972727, 16.54352574],
#        [36.4273961 , 36.86462013],
#        [16.30987879, 16.6067987 ],
#        [12.94174171, 17.39177489],
#        [11.54039994, 14.33546596],
#        [39.12995816, 41.13614985],
#        [14.48150119, 17.0288554 ],
#        [25.51076923, 27.92384615],
#        [19.06782541, 25.37542872],
#        [24.27333333, 26.02222222],
#        [10.67      , 13.965     ],
#        [12.65374148, 15.48288447],
#        [28.96916667, 31.3025    ],
#        [32.06637121, 33.90587413],
#        [32.4600579 , 33.66437662],
#        [12.52409018, 14.10270951],
#        [32.07197078, 33.77470779],
#        [15.21076923, 17.95384615],
#        [36.4273961 , 36.86462013],
#        [10.32466667, 13.49066667],
#        [19.06782541, 25.37542872],
#        [25.51076923, 27.92384615],
#        [39.11240634, 41.18170523],
#        [14.30733438, 16.78037356],
#        [15.21076923, 17.95384615],
#        [12.21421982, 15.00660693],
#        [32.4600579 , 33.66437662],
#        [10.32466667, 13.49066667],
#        [12.21421982, 15.00660693],
#        [12.17774322, 14.97046651],
#        [39.0821443 , 41.18131219],
#        [11.21315898, 14.28001196],
#        [26.32      , 28.603125  ],
#        [39.0821443 , 41.18131219],
#        [32.49034586, 33.35428671],
#        [10.67      , 13.965     ],
#        [23.56      , 26.71615385],
#        [16.47645783, 16.73685165],
#        [15.1053352 , 19.22543109],
#        [25.51076923, 27.92384615],
#        [32.48832314, 33.37321096],
#        [39.11240634, 41.18170523],
#        [32.48832314, 33.37321096],
#        [14.49485944, 16.92103682],
#        [35.61588271, 36.78152056],
#        [28.96916667, 31.3025    ],
#        [11.48122543, 14.30436423],
#        [14.34954469, 15.14059429],
#        [29.05386364, 30.68274148],
#        [25.51076923, 27.92384615],
#        [24.27333333, 26.02222222],
#        [29.00080087, 34.05160181],
#        [12.47805855, 14.07989042],
#        [16.30987879, 16.6067987 ],
#        [14.42735289, 16.98255975],
#        [26.32      , 28.603125  ],
#        [12.17774322, 14.97046651],
#        [24.27333333, 26.02222222],
#        [40.043125  , 39.599375  ],
#        [16.62187179, 16.85298936],
#        [29.05386364, 30.68274148],
#        [14.42793936, 16.75372308],
#        [ 7.34787492, 12.22531453],
#        [36.41545779, 36.85908766],
#        [36.00271808, 38.47570084],
#        [23.56      , 26.71615385],
#        [19.06782541, 25.37542872],
#        [31.94746023, 33.69322727],
#        [10.32466667, 13.49066667],
#        [29.27466667, 31.22266667],
#        [41.90538462, 43.39538462],
#        [12.94323402, 15.94223909],
#        [12.21421982, 15.00660693],
#        [19.06782541, 25.37542872],
#        [18.63667754, 21.58320324],
#        [32.01888636, 33.73334416],
#        [32.06816667, 33.72732867],
#        [14.98759127, 19.1580886 ],
#        [12.20476527, 14.99684935],
#        [15.16918882, 19.2571576 ],
#        [11.51603749, 14.45692641],
#        [36.03298011, 38.47609389],
#        [26.32      , 28.603125  ],
#        [40.043125  , 39.599375  ],
#        [35.61588271, 36.78152056],
#        [12.17774322, 14.97046651],
#        [12.21421982, 15.00660693],
#        [35.61588271, 36.78152056],
#        [12.20476527, 14.99684935],
#        [40.043125  , 39.599375  ],
#        [14.20960738, 16.73211715],
#        [28.5075    , 29.769375  ],
#        [12.17774322, 14.97046651],
#        [32.14769814, 33.47283217],
#        [31.98860633, 33.72905844],
#        [24.27333333, 26.02222222],
#        [36.03298011, 38.47609389],
#        [12.17774322, 14.97046651],
#        [36.34801948, 36.81904221],
#        [ 7.34787492, 12.22531453],
#        [29.05386364, 30.68274148],
#        [24.27333333, 26.02222222],
#        [32.03082468, 33.73887662],
#        [14.23963161, 16.55549703],
#        [16.74978406, 20.28296242],
#        [18.66633677, 21.61755139],
#        [28.96916667, 31.3025    ],
#        [10.67      , 13.965     ],
#        [35.97551029, 38.45037616],
#        [16.30987879, 16.6067987 ],
#        [28.96916667, 31.3025    ],
#        [36.33209334, 36.81343831],
#        [12.65374148, 15.48288447],
#        [14.43465212, 15.21476348],
#        [28.5075    , 29.769375  ],
#        [11.48260242, 14.41300108],
#        [14.34473661, 15.13146929],
#        [14.4015677 , 15.2055491 ],
#        [14.42544438, 17.00061741],
#        [32.01888636, 33.73334416],
#        [28.96916667, 31.3025    ],
#        [23.56      , 26.71615385],
#        [12.94323402, 15.94223909],
#        [24.27333333, 26.02222222],
#        [39.12995816, 41.13614985],
#        [12.21421982, 15.00660693],
#        [24.27333333, 26.02222222],
#        [32.4600579 , 33.66437662],
#        [12.8840595 , 15.91113736],
#        [18.69732534, 21.6666786 ],
#        [12.92848402, 15.94037546],
#        [32.14972086, 33.45390793],
#        [14.43465212, 15.21476348],
#        [32.14972086, 33.45390793],
#        [40.043125  , 39.599375  ],
#        [12.20476527, 14.99684935],
#        [29.00080087, 34.05160181],
#        [41.90538462, 43.39538462],
#        [32.07197078, 33.77470779],
#        [24.27333333, 26.02222222],
#        [29.27466667, 31.22266667],
#        [25.51076923, 27.92384615],
#        [14.3192052 , 16.61208187],
#        [24.27333333, 26.02222222],
#        [10.32466667, 13.49066667],
#        [41.90538462, 43.39538462],
#        [29.27466667, 31.22266667],
#        [11.1182851 , 13.72015266],
#        [13.92688431, 16.43032651],
#        [23.56      , 26.71615385],
#        [10.67      , 13.965     ],
#        [12.21421982, 15.00660693],
#        [25.51076923, 27.92384615],
#        [14.31646026, 15.13137991],
#        [12.44497413, 14.07067604],
#        [12.20476527, 14.99684935],
#        [18.68032728, 21.62938177],
#        [10.67      , 13.965     ],
#        [15.21076923, 17.95384615],
#        [12.90796237, 15.92792308],
#        [15.21076923, 17.95384615],
#        [24.27333333, 26.02222222],
#        [10.67      , 13.965     ],
#        [26.97015341, 31.64419318],
#        [14.42861951, 16.78092117],
#        [12.19594019, 14.9857414 ],
#        [ 6.72794148, 11.7734517 ],
#        [16.90701578, 20.32604593],
#        [23.56      , 26.71615385],
#        [35.61588271, 36.78152056],
#        [10.67      , 13.965     ],
#        [15.21076923, 17.95384615],
#        [12.17774322, 14.97046651],
#        [12.65374148, 15.48288447],
#        [23.56      , 26.71615385],
#        [14.49062814, 16.93881784],
#        [29.27466667, 31.22266667],
#        [28.96916667, 31.3025    ],
#        [12.17774322, 14.97046651],
#        [12.44497413, 14.07067604],
#        [24.27333333, 26.02222222],
#        [25.51076923, 27.92384615],
#        [32.40833333, 34.76666667],
#        [12.17774322, 14.97046651],
#        [39.10275036, 41.11082517],
#        [12.21421982, 15.00660693],
#        [14.05132606, 16.50336343],
#        [11.48260242, 14.41300108],
#        [35.98516626, 38.52125622],
#        [32.40833333, 34.76666667],
#        [32.03082468, 33.73887662],
#        [12.46160117, 14.07427395],
#        [14.31646026, 15.13137991],
#        [15.21076923, 17.95384615],
#        [ 6.72794148, 11.7734517 ]])

# %% [markdown]
# All the above code will be saved in *model.py* so we can easily produce our model.
#
# ---
